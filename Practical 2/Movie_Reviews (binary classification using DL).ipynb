# %% [markdown]
# ## Aim: Binary classification using Deep Neural Networks Example: Classify movie reviews intopositive" reviews and "negative" reviews, just based on the text content of the reviews.Use IMDB dataset

# %%
from keras.datasets import imdb
# %matplotlib inline
import numpy as np
import pandas as pd
from matplotlib import cm
import matplotlib.pyplot as plt
import seaborn as sns
import os
import time

# %%
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalMaxPooling1D
from keras.callbacks import EarlyStopping
from keras import models

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data()
X = np.concatenate((X_train, X_test), axis=0)
y = np.concatenate((y_train, y_test), axis=0)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 3s 0us/step

# %%
##training data shape review
print("Training data: ")
print(X.shape)
print(y.shape)
print("Classes: ")
print(np.unique(y))
# Out:
# Training data:
# (50000,)
# (50000,)
# Classes:
# [0 1]

# %%
print("Number of words: ")
print(len(np.unique(np.hstack(X))))
# Out:
# Number of words:
# 88585

# %%
print("Review length: ")
result = [len(x) for x in X]
print("Mean %.2f words (%f)" % (np.mean(result), np.std(result)))
# plot review length
plt.boxplot(result)
plt.show()
# Out:
# Review length:
# Mean 234.76 words (172.911495)

# %%
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=5000)

# %%
def vectorize_sequences(sequences, dimension=5000):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.  # set specific indices of results[i] to 1s
    return results

# %%
# Our vectorized training data
x_train = vectorize_sequences(train_data)
# Our vectorized test data
x_test = vectorize_sequences(test_data)

# %%
# Our vectorized labels one-hot encoder
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %%
from keras import layers
from keras import models

model = models.Sequential()
model.add(layers.Dense(32, activation='relu', input_shape=(5000,)))
model.add(layers.Dense(32, activation='relu',))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
#Set validation set aside

x_val = x_train[:10000]
partial_x_train = x_train[10000:]

y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['acc'])

# %%
start_time_m1 = time.time()
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
total_time_m1 = time.time() - start_time_m1
# Out:
# Epoch 1/20
# 30/30 [==============================] - 3s 40ms/step - loss: 0.5208 - acc: 0.7642 - val_loss: 0.3402 - val_acc: 0.8629
# Epoch 2/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.2649 - acc: 0.9001 - val_loss: 0.2896 - val_acc: 0.8845
# Epoch 3/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.1946 - acc: 0.9267 - val_loss: 0.2935 - val_acc: 0.8833
# Epoch 4/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.1598 - acc: 0.9429 - val_loss: 0.3141 - val_acc: 0.8771
# Epoch 5/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.1350 - acc: 0.9503 - val_loss: 0.3387 - val_acc: 0.8737
# Epoch 6/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.1140 - acc: 0.9612 - val_loss: 0.3678 - val_acc: 0.8689
# Epoch 7/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.1008 - acc: 0.9654 - val_loss: 0.4004 - val_acc: 0.8686
# Epoch 8/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0864 - acc: 0.9720 - val_loss: 0.4356 - val_acc: 0.8636
# Epoch 9/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0712 - acc: 0.9793 - val_loss: 0.4734 - val_acc: 0.8627
# Epoch 10/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0594 - acc: 0.9824 - val_loss: 0.5168 - val_acc: 0.8568
# Epoch 11/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0498 - acc: 0.9870 - val_loss: 0.5571 - val_acc: 0.8582
# Epoch 12/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0399 - acc: 0.9923 - val_loss: 0.6056 - val_acc: 0.8541
# Epoch 13/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0346 - acc: 0.9928 - val_loss: 0.6455 - val_acc: 0.8535
# Epoch 14/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0315 - acc: 0.9935 - val_loss: 0.6878 - val_acc: 0.8526
# Epoch 15/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0240 - acc: 0.9967 - val_loss: 0.7272 - val_acc: 0.8518
# Epoch 16/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0170 - acc: 0.9990 - val_loss: 0.7664 - val_acc: 0.8521
# Epoch 17/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0127 - acc: 0.9997 - val_loss: 0.8080 - val_acc: 0.8512
# Epoch 18/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0100 - acc: 0.9997 - val_loss: 0.8484 - val_acc: 0.8510
# Epoch 19/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0077 - acc: 0.9999 - val_loss: 0.8777 - val_acc: 0.8517
# Epoch 20/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0062 - acc: 0.9999 - val_loss: 0.9073 - val_acc: 0.8514

# %%
print("The Dense Convolutional Neural Network 1 layer took %.4f seconds to train." % (total_time_m1))
# Out:
# The Dense Convolutional Neural Network 1 layer took 16.4523 seconds to train.

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()   # clear figure
acc_values = history_dict['acc']
val_acc_values = history_dict['val_acc']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                160032
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 161,121
# Trainable params: 161,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, auc
#predictions
pred = model.predict(x_test)
classes_x=np.argmax(pred,axis=1)

#accuracy
accuracy_score(y_test,classes_x)
# Out:
# 782/782 [==============================] - 2s 2ms/step
# 0.5

# %%
#Confusion Matrix
conf_mat = confusion_matrix(y_test, classes_x)
print(conf_mat)

conf_mat_normalized = conf_mat.astype('float') / conf_mat.sum(axis=1)[:, np.newaxis]
sns.heatmap(conf_mat_normalized)
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# [[12500     0]
#  [12500     0]]
# Text(0.5, 23.52222222222222, 'Predicted label')

# %%
#Dense with Two Layer
model2 = models.Sequential()
model2.add(layers.Dense(32, activation='relu', input_shape=(5000,)))
model2.add(layers.Dense(32, activation='relu'))
model2.add(layers.Dense(32, activation='relu'))
model2.add(layers.Dense(1, activation='sigmoid'))

# %%
model2.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['acc'])

# %%
start_time_m2 = time.time()
history= model2.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
total_time_m2 = time.time() - start_time_m2

print("The Dense Convolutional Neural Network 2 layers took %.4f seconds to train." % (total_time_m2))
# Out:
# Epoch 1/20
# 30/30 [==============================] - 13s 99ms/step - loss: 0.5770 - acc: 0.7431 - val_loss: 0.3853 - val_acc: 0.8587
# Epoch 2/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.2841 - acc: 0.8948 - val_loss: 0.2857 - val_acc: 0.8847
# Epoch 3/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.1960 - acc: 0.9257 - val_loss: 0.3046 - val_acc: 0.8796
# Epoch 4/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.1580 - acc: 0.9410 - val_loss: 0.3265 - val_acc: 0.8751
# Epoch 5/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.1283 - acc: 0.9551 - val_loss: 0.3670 - val_acc: 0.8690
# Epoch 6/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.1088 - acc: 0.9621 - val_loss: 0.4021 - val_acc: 0.8667
# Epoch 7/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0885 - acc: 0.9708 - val_loss: 0.4535 - val_acc: 0.8611
# Epoch 8/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0705 - acc: 0.9785 - val_loss: 0.5046 - val_acc: 0.8574
# Epoch 9/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0529 - acc: 0.9866 - val_loss: 0.5688 - val_acc: 0.8602
# Epoch 10/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0377 - acc: 0.9917 - val_loss: 0.6211 - val_acc: 0.8576
# Epoch 11/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0253 - acc: 0.9960 - val_loss: 0.6808 - val_acc: 0.8562
# Epoch 12/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0164 - acc: 0.9983 - val_loss: 0.7509 - val_acc: 0.8535
# Epoch 13/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0100 - acc: 0.9994 - val_loss: 0.8117 - val_acc: 0.8528
# Epoch 14/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0063 - acc: 0.9998 - val_loss: 0.8630 - val_acc: 0.8525
# Epoch 15/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0041 - acc: 0.9999 - val_loss: 0.9149 - val_acc: 0.8533
# Epoch 16/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0026 - acc: 0.9999 - val_loss: 0.9586 - val_acc: 0.8532
# Epoch 17/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0017 - acc: 0.9999 - val_loss: 0.9937 - val_acc: 0.8523
# Epoch 18/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 1.0308 - val_acc: 0.8530
# Epoch 19/20
# 30/30 [==============================] - 1s 19ms/step - loss: 9.6552e-04 - acc: 1.0000 - val_loss: 1.0579 - val_acc: 0.8518
# Epoch 20/20
# 30/30 [==============================] - 1s 19ms/step - loss: 7.6862e-04 - acc: 1.0000 - val_loss: 1.0867 - val_acc: 0.8524
# The Dense Convolutional Neural Network 2 layers took 24.3673 seconds to train.

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('DNN 2 layer Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()   # clear figure
acc_values = history_dict['acc']
val_acc_values = history_dict['val_acc']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('DNN 2 layer Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 32)                160032
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dense_5 (Dense)             (None, 32)                1056
#
#  dense_6 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 162,177
# Trainable params: 162,177
# Non-trainable params: 0
# _________________________________________________________________

# %%
from numpy.ma.core import argmax
pred = model2.predict(x_test)
classes_x=argmax(pred,axis=-1)
#accuracy
accuracy_score(y_test,classes_x)
# Out:
# 782/782 [==============================] - 2s 2ms/step
# 0.5
